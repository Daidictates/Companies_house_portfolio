# %% [markdown]
# ## Import required libraries and set default values

# %%
import xlsxwriter
import numpy as np
import pandas as pd
import datetime as dt
from companies_house.api import CompaniesHouseAPI
date = dt.date.today()

# %% [markdown]
# ## Request API access

# %%
##  if issues renew here https://developer.companieshouse.gov.uk/

#Insert your key here
API_key=r'YOURKEYHERE'
ch1=CompaniesHouseAPI(API_key)

# %% [markdown]
# ## Input file is Excel or xls compatible file with column labelled "Company_numbers"

# %% [markdown]
# ## Location of excel file containing Companies House company numbers

# %%
#Insert your file location here
file=r'YOUR FILE LOCATION'

# %%
Company_list= pd.read_excel(file)

# %%
Company_list['Company_numbers'] = Company_list[Company_list.columns[2]]

# %% [markdown]
# ## Use an excel or csv file to provide a set of company numbers

# %%
Cleaned_company_df = Company_list.dropna()
Clean_company_list = Cleaned_company_df['Company_numbers'].tolist()

# %% [markdown]
# ## Request info for all portfolio companies

# %%
Company_info=[]
for company in Clean_company_list:
    portfolio_information = ch1.get_company(company)
    Company_info.append(portfolio_information)

# %% [markdown]
# ## Clean the list and isolate desired fields

# %%
Company_info_cleaned = list(filter(None, Company_info))

# %% [markdown]
# ## Create overdue accounts list

# %%
df = pd.DataFrame(Company_info_cleaned)

# %%
overdue_true_or_false=[]
for i in range(len(Company_info_cleaned)):
    try:
        overdue_true_or_false_answer = Company_info_cleaned[i]['accounts']['overdue']
    except:
        overdue_true_or_false_answer = Company_info_cleaned[i]['company_status']
    overdue_true_or_false.append(overdue_true_or_false_answer)

# %%
df['overdue_accounts']=pd.Series(overdue_true_or_false, index=df.index)

# %% [markdown]
# ## Trim and colour the rows

# %%
Details_df=df[['company_name','company_status','date_of_cessation','company_number','overdue_accounts',]]

# %% [markdown]
# ## Limited to 20 here to reduce info and print out but comment for normal use

# %%
Details_df =Details_df[0:20]
Details_df
# Out:
#                          company_name company_status date_of_cessation  \
# 0                        &SISTERS LTD         active               NaN
# 1                    AFFRESOL LIMITED    liquidation               NaN
# 2                      ANGELBERRY LTD         active               NaN
# 3                        ARTIS FS LTD         active               NaN
# 4           ASTERLEY BROS, LONDON LTD         active               NaN
# 5           ATLANTIC SEAWEEDS LIMITED         active               NaN
# 6                    CANDIDATE ID LTD         active               NaN
# 7       CELL GUIDANCE SYSTEMS LIMITED         active               NaN
# 10                 CHIP FINANCIAL LTD         active               NaN
# 11          COMPARE AND SHARE LIMITED      dissolved        2016-10-04
# 12           CRUMPET CASHMERE LIMITED      dissolved        2017-05-07
# 13                   CURVE OS LIMITED         active               NaN
# 14                    DINE IN LIMITED      dissolved        2018-01-03
# 15  EARWIG ACADEMIC REPORTING LIMITED         active               NaN
# 16     EAST END MANUFACTURING LIMITED      dissolved        2019-04-23
# 18                  EMONEYHUB LIMITED         active               NaN
# 19                     FANTOO LIMITED    liquidation               NaN
#
#    company_number overdue_accounts
# 0        10510951              NaN
# 1        06441554             True
# 2        07806300             True
# 3        10314551              NaN
# 4        09295823              NaN
# 5        08340701              NaN
# 6        SC516384              NaN
# 7        07122793              NaN
# 10       10113174              NaN
# 11       08365213             True
# 12       08277744             True
# 13       09523903              NaN
# 14       07458196             True
# 15       08304947              NaN
# 16       08190374             True
# 18       08158588              NaN
# 19       08026850             True

# %%
Details_df['overdue_accounts']=Details_df['overdue_accounts'].apply(lambda x:'True' if x else np.nan)

# %% [markdown]
# ## Use Groupby to eliminate any duplicates from follow on rounds

# %%
Details_df.groupby('company_status').count()
# Out:
#                 company_name  date_of_cessation  company_number  \
# company_status
# active                    11                  0              11
# dissolved                  4                  4               4
# liquidation                2                  0               2
#
#                 overdue_accounts
# company_status
# active                         1
# dissolved                      4
# liquidation                    2

# %% [markdown]
# ## Create alphabetical company list and use traffic light colours to indicate status

# %%
Details_df = Details_df.sort_values(by=['company_name'])
#Details_df =Details_df.set_index('company_name')
Details_df = Details_df.drop_duplicates()

# %%
def Company_status_traffic_lights(s):
    if s.company_status =="active":
        return ['background-color: green']*(len(Details_df.columns))
    elif s.company_status=="dissolved":
        return['background-color: red']*(len(Details_df.columns))
    else:
        return ['background-color: orange']*(len(Details_df.columns))

# %%
df_traffic_light= Details_df.style.apply(Company_status_traffic_lights,axis=1)

# %%
df_traffic_light
# Out:
# <style  type="text/css" >
#     #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row0_col0 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row0_col1 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row0_col2 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row0_col3 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row0_col4 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row1_col0 {
#             background-color:  orange;
#             background-color:  orange;
#             background-color:  orange;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row1_col1 {
#             background-color:  orange;
#             background-color:  orange;
#             background-color:  orange;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row1_col2 {
#             background-color:  orange;
#             background-color:  orange;
#             background-color:  orange;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row1_col3 {
#             background-color:  orange;
#             background-color:  orange;
#             background-color:  orange;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row1_col4 {
#             background-color:  orange;
#             background-color:  orange;
#             background-color:  orange;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row2_col0 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row2_col1 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row2_col2 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row2_col3 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row2_col4 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row3_col0 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row3_col1 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row3_col2 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row3_col3 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row3_col4 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row4_col0 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row4_col1 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row4_col2 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row4_col3 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row4_col4 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row5_col0 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row5_col1 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row5_col2 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row5_col3 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row5_col4 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row6_col0 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row6_col1 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row6_col2 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row6_col3 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row6_col4 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row7_col0 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row7_col1 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row7_col2 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row7_col3 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row7_col4 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row8_col0 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row8_col1 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row8_col2 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row8_col3 {
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }    #T_cfe94c86_8eec_11ea_a626_f8633f74c1c3row8_col4 {
#             background-color:  green;
#             background-color:  gre

# %%
DF_portfolio_hit_ratio = Details_df.groupby(['company_status',]).count()

# %%
DF_portfolio_hit_ratio = DF_portfolio_hit_ratio.filter(['company_name','overdue_accounts']).reset_index()

# %%
Dead_companies = Details_df.dropna(subset=['date_of_cessation']).sort_values(by=['date_of_cessation'])

# %%
Dead_companies.drop(['overdue_accounts'],axis=1)
# Out:
#                       company_name company_status date_of_cessation  \
# 11       COMPARE AND SHARE LIMITED      dissolved        2016-10-04
# 12        CRUMPET CASHMERE LIMITED      dissolved        2017-05-07
# 14                 DINE IN LIMITED      dissolved        2018-01-03
# 16  EAST END MANUFACTURING LIMITED      dissolved        2019-04-23
#
#    company_number
# 11       08365213
# 12       08277744
# 14       07458196
# 16       08190374

# %% [markdown]
# ## Save output as an excel

# %%
#Set your output drive here

path = r'Path to store your portfolio'.format(date)


# Turn DFs to excel sheets and sort format

dfs = {'Hit_Ratio':DF_portfolio_hit_ratio,'Dead company timeline':Dead_companies}
writer = pd.ExcelWriter(path, engine='xlsxwriter')
for sheetname, df in dfs.items():  # loop through `dict` of dataframes
    df.to_excel(writer, sheet_name=sheetname,index=False)  # send df to writer
    worksheet = writer.sheets[sheetname]  # pull worksheet object
    for idx, col in enumerate(df):  # loop through all columns
        series = df[col]
        max_len = max((
            series.astype(str).map(len).max(),  # len of largest item
            len(str(series.name))  # len of column name/header
            )) + 10  # adding a little extra space
        fmt = writer.book.add_format({'align': 'center', 'valign': 'vcenter', 'text_wrap': True})
        worksheet.set_column(idx, idx, max_len,fmt)  

# Turn Traffic Light styler object to excel 

#format1 = workbook.add_format({'bg_color': '#FFC7CE','font_color': '#9C0006'})
# Note columns not auto-widened 
        
df_traffic_light.to_excel(writer,sheet_name='colour_coded',index=False)

writer.save()

writer.close()

# %% [markdown]
# ## Citing companies_house_portfolio_assessment_tool

# %% [markdown]
# If you have found this useful please cite as below.

# %% [markdown]
# <blockquote> {companies_house_portfolio_assessment_tool,<br/>author = {Dai},<br/> title = {Companies_House_Portfolio_API},<br/>year = {2020},<br/>publisher = {GitHub},<br/>journal = {GitHub repository},<br/>howpublished = (https://github.com/Daidictates/Companies_house_portfolio),
# }</blockquote>

# %% [markdown]
# # Acknowledgements
#
# #### Thanks to all the library makers we've leant on
